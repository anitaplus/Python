# %% [markdown]
# ## Assignment No 1
# Task 1
# 1 Install Jupyter notebook and run the first program and share the screenshot of the output.
# 2 Write a program which will find all such numbers which are divisible by 7 but are not a multiple
# of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a
# comma-separated sequence on a single line.

# %%
a=list(range(20000,32000))
#print(list(a))
b=[]
for i in a:
    c=i%7
    d=i%5
    if (c==0) & (d!=0):
        b.append(i)  
print(b)
# Out:
# [20006, 20013, 20027, 20034, 20041, 20048, 20062, 20069, 20076, 20083, 20097, 20104, 20111, 20118, 20132, 20139, 20146, 20153, 20167, 20174, 20181, 20188, 20202, 20209, 20216, 20223, 20237, 20244, 20251, 20258, 20272, 20279, 20286, 20293, 20307, 20314, 20321, 20328, 20342, 20349, 20356, 20363, 20377, 20384, 20391, 20398, 20412, 20419, 20426, 20433, 20447, 20454, 20461, 20468, 20482, 20489, 20496, 20503, 20517, 20524, 20531, 20538, 20552, 20559, 20566, 20573, 20587, 20594, 20601, 20608, 20622, 20629, 20636, 20643, 20657, 20664, 20671, 20678, 20692, 20699, 20706, 20713, 20727, 20734, 20741, 20748, 20762, 20769, 20776, 20783, 20797, 20804, 20811, 20818, 20832, 20839, 20846, 20853, 20867, 20874, 20881, 20888, 20902, 20909, 20916, 20923, 20937, 20944, 20951, 20958, 20972, 20979, 20986, 20993, 21007, 21014, 21021, 21028, 21042, 21049, 21056, 21063, 21077, 21084, 21091, 21098, 21112, 21119, 21126, 21133, 21147, 21154, 21161, 21168, 21182, 21189, 21196, 21203, 21217, 21224, 21231, 21238, 21252, 21259, 21266, 21273, 21287, 21294, 21301, 21308, 21322, 21329, 21336, 21343, 21357, 21364, 21371, 21378, 21392, 21399, 21406, 21413, 21427, 21434, 21441, 21448, 21462, 21469, 21476, 21483, 21497, 21504, 21511, 21518, 21532, 21539, 21546, 21553, 21567, 21574, 21581, 21588, 21602, 21609, 21616, 21623, 21637, 21644, 21651, 21658, 21672, 21679, 21686, 21693, 21707, 21714, 21721, 21728, 21742, 21749, 21756, 21763, 21777, 21784, 21791, 21798, 21812, 21819, 21826, 21833, 21847, 21854, 21861, 21868, 21882, 21889, 21896, 21903, 21917, 21924, 21931, 21938, 21952, 21959, 21966, 21973, 21987, 21994, 22001, 22008, 22022, 22029, 22036, 22043, 22057, 22064, 22071, 22078, 22092, 22099, 22106, 22113, 22127, 22134, 22141, 22148, 22162, 22169, 22176, 22183, 22197, 22204, 22211, 22218, 22232, 22239, 22246, 22253, 22267, 22274, 22281, 22288, 22302, 22309, 22316, 22323, 22337, 22344
b=input('Enter Last Name ')
print(a[::-1],b[::-1])
# Out:
# Enter First  nameAnita
# Enter Last Name Shinde
# atinA ednihS

# %% [markdown]
# 3.Write a Python program to find the volume of a sphere with diameter 12 cm.
# Formula: V=4/3 * π * r

# %%
r=12 
v=4/3* 22/7 * r
print('The volume of sphere with diameter 12 is ',  v)
# Out:
# The volume of sphere with diameter 12 is  50.28571428571429

# %% [markdown]
# # Task 2
# *
# 1.
# Write a program which accepts a sequence of comma-separated numbers from console and
# generate a list.
# 2.Create the below pattern using nested for loop in Python
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
# 3.
# Write a Python program to reverse a word after accepting the input from the user.
# Sample Output:
# Input word: AcadGild
# Output: dilGdacA
# 4
# 4.
# Write a Python Program to print the given string in the format specified in the sample output.
# WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a
# SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all
# its citizens
# Sample Output:
# WE, THE PEOPLE OF INDIA,
# having solemnly resolved to constitute India into a SOVEREIGN, !
# SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# and to secure to all its citizens

# %%
# 1.Write a program which accepts a sequence of comma-separated numbers from console and generate a list.
b=input('Enter  list elements with comma seprated no:')
l=b.split(',')
print("List is",l)
# Out:
# Enter  list elements with comma seprated no:23,33,222222,344,444,33568990,098
# List is ['23', '33', '222222', '344', '444', '33568990', '098']

# %%
# solution 1
a=5
i=0
b='*'
while i<=5:
    print(i*b)
    i=i+1
    if a<=1:
        print(a*b)
        a=a-1
for i in range(5,0,-1):
    for j in range(0,i-1):
        print(b,end='')
    print("")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
# Solution 2
b='*'
for i in range(0,5):
    for j in range(0,i+1):
        print("*",end=' ')
    print("\r")
for i in range(5,0,-1):
    for j in range(0,i-1):
        print("*",end=' ')
    print("")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
# 3.
a=input('write any word which want to reverse:')
b=a[::-1]
print(b)
# Out:
# write any word which want to reverse:ASKDDJFHFHFHFFHFHFSdkdjo
# ojdkdSFHFHFFHFHFHFJDDKSA

# %%
s='WE, THE PEOPLE OF INDIA,\n\thaving solemnly resolved to constitute India into a SOVEREIGN {} , \n\t\tSOCIALIST, SECULAR, DEMOCRATIC REPUBLIC \n\t\tand to secure to all its citizens'.format("!")
s.expandtabs()
print(s)
# Out:
# WE, THE PEOPLE OF INDIA,
# 	having solemnly resolved to constitute India into a SOVEREIGN ! ,
# 		SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# 		and to secure to all its citizens
